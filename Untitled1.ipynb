# %%
name="sam"

# %%
name
# Out:
# 'sam'

# %%
#name[0]="p"

# %%
last_name=name[1:]

# %%
last_name
# Out:
# 'am'

# %%
'p'+last_name
# Out:
# 'pam'

# %%
x = 'hello '

# %%
x = x + " hey you!"

# %%
x
# Out:
# 'hellohey you! hey you! hey you! hey you!'

# %%
x = 'hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['hello', 'world']

# %%
x.split('o')
# Out:
# ['hell', ' w', 'rld']
