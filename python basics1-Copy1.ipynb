# %%
2+3
# Out:
# 5

# %%
a=5

# %%
a+a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
mystring='abcdefghi'

# %%
mystring
# Out:
# 'abcdefghi'

# %%
mystring[:2]
# Out:
# 'ab'

# %%
mystring[3:]
# Out:
# 'defghi'

# %%
mystring[3:5]
# Out:
# 'de'

# %%
mystring[::]
# Out:
# 'abcdefghi'

# %%
mystring[::2]
# Out:
# 'acegi'

# %%
mystring[2:5:2]
# Out:
# 'ce'

# %%
mystring[::-1]
# Out:
# 'ihgfedcba'
